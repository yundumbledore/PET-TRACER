# %%
from PetTracer import *

device = torch.device('cuda:0' if torch.cuda.is_available() else 'mps' if torch.backends.mps.is_available() else 'cpu')
print(device)
# Out:
# mps

# %%
# Load model
model = get_model(device)

# %%
data_path = './Sample_data/P001_PET_coronal_116_denoised_adjusted.h5'
tbpet_inference(model, device, data_path, sample_size = 1000, num_timesteps = 3, batch_size = 500)
# Out:
# 66154
#   0%|                                                   | 0/133 [00:02<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 data_path = './Sample_data/P001_PET_coronal_116_denoised_adjusted.h5'
# ----> 2 tbpet_inference(model, device, data_path, sample_size = 1000, num_timesteps = 3, batch_size = 500)
#
# File ~/Documents/GitHub/PET-TRACER/PetTracer.py:116, in tbpet_inference(model, device, data_path, sample_size, num_timesteps, batch_size)
#     113 batch_np = y_norm[i:i+batch_size]
#     114 obs      = torch.tensor(batch_np, dtype=torch.float32, device=device)
# --> 116 theta_hat_cpu = Sampler(model, obs, sample_size, t_list)
#     118 x_pred = theta_hat_cpu * x_std + x_mean
#     120 samples = x_pred.cpu().numpy()
#
# File ~/Documents/GitHub/PET-TRACER/PetTracer.py:29, in Sampler(model, y, num_posterior_samples, t)
#      26         x_noisy = x_noisy + t[j] * z
#      28     with torch.no_grad():
# ---> 29         x_noisy = model(x_noisy, y_repeated, t_tensor)  # Apply the trained model
#      31 x_noisy = x_noisy.view(batch_size, num_posterior_samples, 5)
#      33 return x_noisy
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/Documents/GitHub/PET-TRACER/model.py:80, in OneDUnet.forward(self, x, y, t)
#      78 h2 = self.conv2(h1)
#      79 h2 += self.dense2(embed)
# ---> 80 h2 = self.gnorm2(h2)
#      81 h2 = self.act(h2)
#      82 h3 = self.conv3(h2)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/normalization.py:287, in GroupNorm.forward(self, input)
#     286 def forward(self, input: Tensor) -> Tensor:
# --> 287     return F.group_norm(
#     288         input, self.num_groups, self.weight, self.bias, self.eps)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/functional.py:2588, in group_norm(input, num_groups, weight, bias, eps)
#    2586     raise RuntimeError(f"Expected at least 2 dimensions for input tensor but received {input.dim()}")
#    2587 _verify_batch_size([input.size(0) * input.size(1) // num_groups, num_groups] + list(input.size()[2:]))
# -> 2588 return torch.group_norm(input, num_groups, weight, bias, eps, torch.backends.cudnn.enabled)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/_refs/__init__.py:3126, in native_group_norm(input, weight, bias, batch_size, num_channels, flattened_inner_size, num_groups, eps)
#    3121 reduction_dims = [2, 3]
#    3122 input_reshaped = torch.reshape(
#    3123     input,
#    3124     [batch_size, num_groups, num_channels // num_groups, flattened_inner_size],
#    3125 )
# -> 3126 out, mean, rstd = _normalize(input_reshaped, reduction_dims, eps)
#    3127 out = out.view(input.shape)
#    3129 broadcast_dims = [0] + list(range(2, input.ndim))
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/_refs/__init__.py:3087, in _normalize(a, norm_dims, eps)
#    3083 assert isinstance(a_acc, TensorLike)  # to avoid mypy error for var_mean
#    3084 biased_var, mean = torch.var_mean(
#    3085     a_acc, dim=norm_dims, unbiased=False, keepdim=True
#    3086 )
# -> 3087 rstd = torch.rsqrt(biased_var + eps)
#    3088 out = (a - mean) * rstd
#    3089 return out, mean, rstd
#
# KeyboardInterrupt:

# %%
slice_index = 116
mask = np.load("P001_mask.npy")
mask_slice = mask[:,slice_index,:]
spacing = np.array([3.3,3.3,1.645])[[0,2]] # P001
estimates = np.load('./Output/tbpet_estimates.npy')
parameter_name = "Ki Posterior Mean"
statistic = estimates[0,:]
parametric_map_interactive(statistic, mask_slice, spacing, parameter_name)

# %%
estimates[0,100:200]
# Out:
# array([0.07070233, 0.07257206, 0.07904651, 0.08688754, 0.07640336,
#        0.07297155, 0.07033065, 0.0695771 , 0.07298446, 0.07006225,
#        0.07089186, 0.08814186, 0.0714148 , 0.07711457, 0.0705378 ,
#        0.06984782, 0.0722096 , 0.07151406, 0.08713426, 0.07410982,
#        0.07443111, 0.07168943, 0.07165571, 0.0734947 , 0.07140967,
#        0.07268424, 0.07728537, 0.08263658, 0.07205085, 0.07129329,
#        0.07084136, 0.07337733, 0.07037523, 0.07217955, 0.07259701,
#        0.07334178, 0.06936438, 0.07480345, 0.07295798, 0.07566452,
#        0.07066463, 0.06974617, 0.07004483, 0.07235911, 0.07255942,
#        0.06961308, 0.07040819, 0.07334854, 0.07103408, 0.07092173,
#        0.07030462, 0.07340843, 0.07259691, 0.07301866, 0.07030877,
#        0.07275954, 0.07175358, 0.07631481, 0.08409876, 0.0763483 ,
#        0.07149258, 0.07446603, 0.07096054, 0.07496995, 0.0710347 ,
#        0.07103112, 0.07055702, 0.07881618, 0.0772597 , 0.0717098 ,
#        0.06917623, 0.07359375, 0.07204346, 0.07117035, 0.07156019,
#        0.07311144, 0.07266629, 0.07296871, 0.07097969, 0.07029414,
#        0.07770225, 0.07222516, 0.07352136, 0.06990976, 0.0698278 ,
#        0.06927611, 0.07533327, 0.07159273, 0.09169222, 0.07520264,
#        0.0719865 , 0.06998736, 0.07058822, 0.07371869, 0.07003574,
#        0.07344851, 0.07553005, 0.07619093, 0.07714274, 0.07111719],
#       dtype=float32)

# %%
estimates[0,100:200]
# Out:
# array([0.01148798, 0.00950012, 0.01753394, 0.02529308, 0.02428554,
#        0.01252421, 0.01038357, 0.01412764, 0.01718401, 0.00932262,
#        0.01056778, 0.03016005, 0.00822442, 0.00674095, 0.00870612,
#        0.0081565 , 0.00759612, 0.01147309, 0.03701771, 0.01841854,
#        0.00955583, 0.01039679, 0.01107252, 0.01255624, 0.01224647,
#        0.01854021, 0.0169652 , 0.02710264, 0.00817778, 0.007397  ,
#        0.00732745, 0.01026744, 0.00996698, 0.01502994, 0.00929589,
#        0.01280802, 0.00714764, 0.01020857, 0.01021854, 0.01272521,
#        0.00879448, 0.00772567, 0.0082091 , 0.00865954, 0.00833448,
#        0.00990494, 0.01135322, 0.01061133, 0.01085821, 0.00976242,
#        0.01234372, 0.00890418, 0.01340712, 0.00878366, 0.00946201,
#        0.01566087, 0.00932305, 0.020882  , 0.02987306, 0.01601555,
#        0.00861238, 0.01068241, 0.00720557, 0.01727294, 0.00886194,
#        0.00945366, 0.0132418 , 0.02256244, 0.02535362, 0.01605477,
#        0.00794542, 0.01391343, 0.00968072, 0.00966103, 0.00968561,
#        0.01181529, 0.01017566, 0.00888106, 0.00698349, 0.01129812,
#        0.0164277 , 0.00919352, 0.01537757, 0.01168581, 0.01089498,
#        0.01049153, 0.01887301, 0.01104502, 0.04066159, 0.01922423,
#        0.01302248, 0.00859177, 0.01400363, 0.02003515, 0.00733124,
#        0.0106188 , 0.01662323, 0.02286533, 0.01826472, 0.01008972],
#       dtype=float32)
