# %%
import os
# This specific line prevents the crash caused by Torch/Scipy/Matplotlib conflicts
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

import sys
sys.path.append('Source')
from PetTracer import *
import torch

device = torch.device('cuda:0' if torch.cuda.is_available() else 'mps' if torch.backends.mps.is_available() else 'cpu')
print(device)
# Out:
# mps

# %%
# Load model
model = get_model(device)

# %% [markdown]
# ### Estimate the posterior of Ki from a TAC from the left frontal cortex

# %%
data_path = './Sample_data/brain_TAC.h5'
plot_TAC(data_path)

# %%
parameter_name = 'Ki'
title = 'Left Frontal Cortex'
Samples = demo_single_TAC(model, device, data_path)
plot_posterior(Samples)

# %% [markdown]
# ### Estimate the posterior of Ki from a TAC from the myocardium¶

# %%
data_path = './Sample_data/myocardium_TAC.h5'
plot_TAC(data_path)

# %%
parameter_name = 'Ki'
title = 'Myocardium'
Samples = demo_single_TAC(model, device, data_path)
plot_posterior(Samples)

# %% [markdown]
# ### Estimate the posterior of Ki from a TAC from the liver inferior right

# %%
data_path = './Sample_data/liverInferiorRight_TAC.h5'
plot_TAC(data_path)

# %%
parameter_name = 'Ki'
title = 'Liver Inferior Right'
Samples = demo_single_TAC(model, device, data_path)
plot_posterior(Samples)
